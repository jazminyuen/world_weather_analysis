# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key
from config import weather_api_key

# %%
# Create URL for OpenWeatherMap
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unzip coordinates into a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | huarmey
# Processing Record 5 of Set 1 | yarada
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | dromolaxia
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | novosergiyevka
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | hatillo
# Processing Record 17 of Set 1 | sioux lookout
# Processing Record 18 of Set 1 | kamenskiy
# Processing Record 19 of Set 1 | guerrero negro
# Processing Record 20 of Set 1 | norsup
# Processing Record 21 of Set 1 | praia
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | chapais
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | constitucion
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | hellvik
# Processing Record 31 of Set 1 | port-cartier
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | zhaotong
# Processing Record 34 of Set 1 | palana
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | berlevag
# Processing Record 37 of Set 1 | boone
# Processing Record 38 of Set 1 | severomuysk
# Processing Record 39 of Set 1 | sarakhs
# Processing Record 40 of Set 1 | noumea
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | black river
# Processing Record 44 of Set 1 | verkhnyaya inta
# Processing Record 45 of Set 1 | yablochnyy
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | monroe
# Processing Record 48 of Set 1 | khromtau
# Processing Record 49 of Set 1 | visnes
# Processing Record 50 of Set 1 | aquiraz
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | viedma
# Processing Record 4 of Set 2 | denau
# City not found. Skipping...
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | saint marys
# Processing Record 9 of Set 2 | oriximina
# Processing Record 10 of Set 2 | tres arroyos
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | port hedland
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | hami
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | australind
# Processing Record 17 of Set 2 | rawson
# Processing Record 18 of Set 2 | qabis
# City not found. Skipping...
# Processing Record 19 of Set 2 | quatre cocos
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | faanui
# Processing Record 22 of Set 2 | inhambane
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | biak
# Processing Record 26 of Set 2 | mosetse
# Processing Record 27 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 2 | dhamrai
# Processing Record 29 of Set 2 | swift current
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | kalcheva
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | praia da vitoria
# Processing Record 39 of Set 2 | high level
# Processing Record 40 of Set 2 | sirjan
# Processing Record 41 of Set 2 | samagaltay
# Processing Record 42 of Set 2 | moerai
# Processing Record 43 of Set 2 | atbasar
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | muros
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | hirado
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | coquimbo
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | narsaq
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | sola
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | ambilobe
# Processing Record 11 of Set 3 | dicabisagan
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | santa rosa
# Processing Record 14 of Set 3 | urumqi
# Processing Record 15 of Set 3 | miri
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | busayra
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | am timan
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | anchorage
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | sangar
# Processing Record 25 of Set 3 | itabirito
# Processing Record 26 of Set 3 | panguna
# Processing Record 27 of Set 3 | bure
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | porto murtinho
# Processing Record 30 of Set 3 | buritis
# Processing Record 31 of Set 3 | yeltsovka
# City not found. Skipping...
# Processing Record 32 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | ewa beach
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | hwange
# Processing Record 37 of Set 3 | weihe
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 3 | ati
# Processing Record 44 of Set 3 | tomatlan
# Processing Record 45 of Set 3 | parras
# City not found. Skipping...
# Processing Record 46 of Set 3 | trairi
# Processing Record 47 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 48 of Set 3 | burica
# City not found. Skipping...
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | emerald
# Processing Record 1 of Set 4 | mumford
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 4 | qaqortoq
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | morehead
# Processing Record 7 of Set 4 | itoman
# Processing Record 8 of Set 4 | canaries
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | mossendjo
# Processing Record 12 of Set 4 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | ibra
# Processing Record 15 of Set 4 | port hawkesbury
# Processing Record 16 of Set 4 | cap malheureux
# Processing Record 17 of Set 4 | tancheng
# Processing Record 18 of Set 4 | tazmalt
# Processing Record 19 of Set 4 | saint-georges
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | port-gentil
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | reo
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | taltal
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 4 | ucluelet
# Processing Record 31 of Set 4 | karatuzskoye
# Processing Record 32 of Set 4 | san quintin
# Processing Record 33 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 4 | havoysund
# Processing Record 35 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 4 | avila
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | mwinilunga
# Processing Record 41 of Set 4 | galle
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | puerto escondido
# Processing Record 46 of Set 4 | pacific grove
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | port lincoln
# Processing Record 49 of Set 4 | itarema
# Processing Record 50 of Set 4 | sao jose da coroa grande
# Processing Record 1 of Set 5 | zhigansk
# Processing Record 2 of Set 5 | domoni
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | waddan
# Processing Record 6 of Set 5 | goderich
# Processing Record 7 of Set 5 | kibre mengist
# Processing Record 8 of Set 5 | porbandar
# Processing Record 9 of Set 5 | hambantota
# Processing Record 10 of Set 5 | bijie
# Processing Record 11 of Set 5 | tyrma
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | kinel-cherkassy
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | coahuayana
# Processing Record 16 of Set 5 | altay
# Processing Record 17 of Set 5 | fort frances
# Processing Record 18 of Set 5 | mezen
# Processing Record 19 of Set 5 | linxia
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | kenai
# Processing Record 22 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 5 | ancud
# Processing Record 24 of Set 5 | kosa
# Processing Record 25 of Set 5 | arrifes
# Processing Record 26 of Set 5 | tinskoy
# Processing Record 27 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 5 | hopelchen
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | lebu
# Processing Record 31 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | meiganga
# Processing Record 34 of Set 5 | berezovyy
# Processing Record 35 of Set 5 | half moon bay
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | mandurah
# Processing Record 39 of Set 5 | macomer
# Processing Record 40 of Set 5 | moratuwa
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | oistins
# Processing Record 43 of Set 5 | jalu
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | haines junction
# Processing Record 46 of Set 5 | strezhevoy
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | haifa
# Processing Record 49 of Set 5 | hobyo
# Processing Record 50 of Set 5 | kalianget
# Processing Record 1 of Set 6 | takoradi
# Processing Record 2 of Set 6 | lamar
# Processing Record 3 of Set 6 | auki
# Processing Record 4 of Set 6 | hithadhoo
# Processing Record 5 of Set 6 | presidencia roque saenz pena
# Processing Record 6 of Set 6 | galesong
# Processing Record 7 of Set 6 | puerto leguizamo
# Processing Record 8 of Set 6 | tashla
# Processing Record 9 of Set 6 | nome
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | pevek
# Processing Record 12 of Set 6 | karratha
# Processing Record 13 of Set 6 | remedios
# Processing Record 14 of Set 6 | mulege
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | saint-joseph
# Processing Record 18 of Set 6 | upernavik
# Processing Record 19 of Set 6 | marawi
# Processing Record 20 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 6 | magomeni
# Processing Record 22 of Set 6 | oranjemund
# Processing Record 23 of Set 6 | ixtapa
# Processing Record 24 of Set 6 | burlington
# Processing Record 25 of Set 6 | yar-sale
# Processing Record 26 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 6 | lander
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | saskylakh
# Processing Record 30 of Set 6 | portland
# Processing Record 31 of Set 6 | timiryazevskiy
# Processing Record 32 of Set 6 | kanakeravan
# Processing Record 33 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 6 | corowa
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | jacareacanga
# Processing Record 38 of Set 6 | vestmannaeyjar
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | milton
# Processing Record 41 of Set 6 | hengshui
# Processing Record 42 of Set 6 | laguna
# Processing Record 43 of Set 6 | srednekolymsk
# Processing Record 44 of Set 6 | belaya gora
# Processing Record 45 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | mafinga
# Processing Record 48 of Set 6 | vao
# Processing Record 49 of Set 6 | lodja
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | nanortalik
# Processing Record 2 of Set 7 | tynda
# Processing Record 3 of Set 7 | mahon
# Processing Record 4 of Set 7 | marzuq
# Processing Record 5 of Set 7 | himora
# City not found. Skipping...
# Processing Record 6 of Set 7 | bani walid
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | dolores
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | kruisfontein
# Processing Record 13 of Set 7 | susanville
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 16 of Set 7 | college
# Processing Record 17 of Set 7 | jiuquan
# Processing Record 18 of Set 7 | vila velha
# Processing Record 19 of Set 7 | road town
# Processing Record 20 of Set 7 | vanimo
# Processing Record 21 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 7 | lashio
# Processing Record 23 of Set 7 | kloulklubed
# Processing Record 24 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 7 | semporna
# Processing Record 26 of Set 7 | kalevala
# Processing Record 27 of Set 7 | bethanien
# Processing Record 28 of Set 7 | sobolevo
# Processing Record 29 of Set 7 | port pirie
# Processing Record 30 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | puksoozero
# Processing Record 34 of Set 7 | fruitvale
# Processing Record 35 of Set 7 | sorland
# Processing Record 36 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 37 of Set 7 | balkanabat
# Processing Record 38 of Set 7 | malmyzh
# Processing Record 39 of Set 7 | lasa
# Processing Record 40 of Set 7 | fort nelson
# Processing Record 41 of Set 7 | santa maria
# Processing Record 42 of Set 7 | inongo
# Processing Record 43 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 7 | terrace
# Processing Record 45 of Set 7 | muisne
# Processing Record 46 of Set 7 | adrar
# Processing Record 47 of Set 7 | chajul
# Processing Record 48 of Set 7 | boden
# Processing Record 49 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 7 | couvin
# Processing Record 1 of Set 8 | camapua
# Processing Record 2 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 8 | nacozari
# Processing Record 4 of Set 8 | hervey bay
# Processing Record 5 of Set 8 | alice springs
# Processing Record 6 of Set 8 | necochea
# Processing Record 7 of Set 8 | kieta
# Processing Record 8 of Set 8 | ca mau
# Processing Record 9 of Set 8 | san jose de guanipa
# Processing Record 10 of Set 8 | vestmanna
# Processing Record 11 of Set 8 | longhua
# Processing Record 12 of Set 8 | sayyan
# Processing Record 13 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | merauke
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | comandau
# Processing Record 19 of Set 8 | bull savanna
# Processing Record 20 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 8 | westport
# Processing Record 23 of Set 8 | basco
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | makakilo city
# Processing Record 26 of Set 8 | lichinga
# Processing Record 27 of Set 8 | rio grande
# Processing Record 28 of Set 8 | slave lake
# Processing Record 29 of Set 8 | tazovskiy
# Processing Record 30 of Set 8 | broken hill
# Processing Record 31 of Set 8 | nishihara
# Processing Record 32 of Set 8 | ponte nova
# Processing Record 33 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 8 | moose factory
# Processing Record 35 of Set 8 | poronaysk
# Processing Record 36 of Set 8 | dunmore town
# Processing Record 37 of Set 8 | nuuk
# Processing Record 38 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 39 of Set 8 | banda aceh
# Processing Record 40 of Set 8 | cartagena del chaira
# Processing Record 41 of Set 8 | laiwu
# Processing Record 42 of Set 8 | liverpool
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | aksu
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | adwa
# Processing Record 48 of Set 8 | darhan
# Processing Record 49 of Set 8 | grants
# Processing Record 50 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 9 | bratsk
# Processing Record 2 of Set 9 | menomonie
# Processing Record 3 of Set 9 | doha
# Processing Record 4 of Set 9 | olga
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | olafsvik
# Processing Record 7 of Set 9 | igarape-acu
# City not found. Skipping...
# Processing Record 8 of Set 9 | kharan
# Processing Record 9 of Set 9 | pemangkat
# Processing Record 10 of Set 9 | katsuura
# Processing Record 11 of Set 9 | mantua
# Processing Record 12 of Set 9 | stokmarknes
# Processing Record 13 of Set 9 | hay river
# Processing Record 14 of Set 9 | ketchikan
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | cabra
# Processing Record 17 of Set 9 | phaphund
# Processing Record 18 of Set 9 | arai
# Processing Record 19 of Set 9 | bachatskiy
# Processing Record 20 of Set 9 | los llanos de aridane
# Processing Record 21 of Set 9 | shenjiamen
# Processing Record 22 of Set 9 | ushtobe
# Processing Record 23 of Set 9 | leh
# Processing Record 24 of Set 9 | sayula
# Processing Record 25 of Set 9 | norman wells
# Processing Record 26 of Set 9 | scarborough
# Processing Record 27 of Set 9 | broome
# Processing Record 28 of Set 9 | nang rong
# Processing Record 29 of Set 9 | calama
# Processing Record 30 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 9 | eyl
# Processing Record 32 of Set 9 | mana
# Processing Record 33 of Set 9 | sechura
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 | del rio
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | andenes
# Processing Record 38 of Set 9 | emborion
# Processing Record 39 of Set 9 | tonstad
# Processing Record 40 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | epe
# Processing Record 42 of Set 9 | pitimbu
# Processing Record 43 of Set 9 | aksarka
# Processing Record 44 of Set 9 | mayskiy
# Processing Record 45 of Set 9 | bowen
# Processing Record 46 of Set 9 | grindavik
# Processing Record 47 of Set 9 | tutoia
# Processing Record 48 of Set 9 | najran
# Processing Record 49 of Set 9 | barth
# Processing Record 50 of Set 9 | ubinskoye
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | pflugerville
# Processing Record 3 of Set 10 | rajmahal
# Processing Record 4 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 10 | kalaleh
# Processing Record 6 of Set 10 | yerbogachen
# Processing Record 7 of Set 10 | aktau
# Processing Record 8 of Set 10 | cascais
# Processing Record 9 of Set 10 | asau
# Processing Record 10 of Set 10 | hohhot
# Processing Record 11 of Set 10 | novo aripuana
# Processing Record 12 of Set 10 | kuah
# Processing Record 13 of Set 10 | oppdal
# Processing Record 14 of Set 10 | darlowo
# Processing Record 15 of Set 10 | yermakovskoye
# Processing Record 16 of Set 10 | northam
# Processing Record 17 of Set 10 | beringovskiy
# Processing Record 18 of Set 10 | te anau
# Processing Record 19 of Set 10 | benghazi
# Processing Record 20 of Set 10 | lincoln
# Processing Record 21 of Set 10 | harrisonburg
# Processing Record 22 of Set 10 | port shepstone
# Processing Record 23 of Set 10 | vallee-jonction
# City not found. Skipping...
# Processing Record 24 of Set 10 | makasar
# Processing Record 25 of Set 10 | kalininsk
# Processing Record 26 of Set 10 | touros
# Processing Record 27 of Set 10 | vangaindrano
# Processing Record 28 of Set 10 | sao filipe
# Processing Record 29 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 10 | san carlos
# Processing Record 32 of Set 10 | sistranda
# Processing Record 33 of Set 10 | tigil
# Processing Record 34 of Set 10 | nemuro
# Processing Record 35 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 10 | kuusamo
# Processing Record 37 of Set 10 | miyako
# Processing Record 38 of Set 10 | kedrovyy
# Processing Record 39 of Set 10 | visby
# Processing Record 40 of Set 10 | turbat
# Processing Record 41 of Set 10 | barra patuca
# Processing Record 42 of Set 10 | karpathos
# Processing Record 43 of Set 10 | wattegama
# Processing Record 44 of Set 10 | phan thiet
# Processing Record 45 of Set 10 | vila franca do campo
# Processing Record 46 of Set 10 | vaasa
# Processing Record 47 of Set 10 | fortuna
# Processing Record 48 of Set 10 | cedar city
# Processing Record 49 of Set 10 | maldonado
# Processing Record 50 of Set 10 | riverton
# Processing Record 1 of Set 11 | bulgan
# Processing Record 2 of Set 11 | kuybysheve
# Processing Record 3 of Set 11 | mackay
# Processing Record 4 of Set 11 | chumikan
# Processing Record 5 of Set 11 | marseille
# Processing Record 6 of Set 11 | fort-shevchenko
# Processing Record 7 of Set 11 | kisesa
# Processing Record 8 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 9 of Set 11 | burnie
# Processing Record 10 of Set 11 | raudeberg
# Processing Record 11 of Set 11 | poum
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | pyaozerskiy
# Processing Record 14 of Set 11 | severo-kurilsk
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | dodge city
# Processing Record 17 of Set 11 | chepareria
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | el penon
# Processing Record 20 of Set 11 | mandalgovi
# Processing Record 21 of Set 11 | antofagasta
# Processing Record 22 of Set 11 | cuenca
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | cayenne
# Processing Record 25 of Set 11 | kutum
# Processing Record 26 of Set 11 | iquitos
# Processing Record 27 of Set 11 | rumphi
# Processing Record 28 of Set 11 | lavrentiya
# Processing Record 29 of Set 11 | ashland
# Processing Record 30 of Set 11 | talnakh
# Processing Record 31 of Set 11 | nhulunbuy
# Processing Record 32 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | soyo
# Processing Record 35 of Set 11 | gornopravdinsk
# Processing Record 36 of Set 11 | tessalit
# Processing Record 37 of Set 11 | maraba
# Processing Record 38 of Set 11 | corbii mari
# Processing Record 39 of Set 11 | leningradskiy
# Processing Record 40 of Set 11 | stornoway
# Processing Record 41 of Set 11 | buala
# Processing Record 42 of Set 11 | shillong
# Processing Record 43 of Set 11 | dingle
# Processing Record 44 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 11 | dongsheng
# Processing Record 46 of Set 11 | baykit
# Processing Record 47 of Set 11 | pandan niog
# Processing Record 48 of Set 11 | kulachi
# Processing Record 49 of Set 11 | mpongwe
# Processing Record 50 of Set 11 | sao joao da barra
# Processing Record 1 of Set 12 | luwuk
# Processing Record 2 of Set 12 | chunskiy
# Processing Record 3 of Set 12 | maroantsetra
# Processing Record 4 of Set 12 | mapiri
# Processing Record 5 of Set 12 | tual
# Processing Record 6 of Set 12 | alyangula
# Processing Record 7 of Set 12 | coihaique
# Processing Record 8 of Set 12 | souflion
# City not found. Skipping...
# Processing Record 9 of Set 12 | sembe
# Processing Record 10 of Set 12 | ouadda
# Processing Record 11 of Set 12 | burgeo
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | corralillo
# Processing Record 14 of Set 12 | kattivakkam
# Processing Record 15 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | akdepe
# Processing Record 17 of Set 12 | puerto narino
# Processing Record 18 of Set 12 | thunder bay
# Processing Record 19 of Set 12 | nokaneng
# Processing Record 20 of Set 12 | heinola
# Processing Record 21 of Set 12 | mahajanga
# Processing Record 22 of Set 12 | matam
# Processing Record 23 of Set 12 | salalah
# Processing Record 24 of Set 12 | carmelo
# Processing Record 25 of Set 12 | medicine hat
# Processing Record 26 of Set 12 | castanos
# Processing Record 27 of Set 12 | chapadinha
# Processing Record 28 of Set 12 | abnub
# Processing Record 29 of Set 12 | svetlyy
# Processing Record 30 of Set 12 | almeirim
# Processing Record 31 of Set 12 | xinzhou
# Processing Record 32 of Set 12 | mgandu
# Processing Record 33 of Set 12 | bubaque
# Processing Record 34 of Set 12 | yalova
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | sanford
# Processing Record 37 of Set 12 | riyadh
# Processing Record 38 of Set 12 | seoul
# Processing Record 39 of Set 12 | varhaug
# Processing Record 40 of Set 12 | krasnoselkup
# Processing Record 41 of Set 12 | kasempa
# Processing Record 42 of Set 12 | mawlaik
# Processing Record 43 of Set 12 | fonte boa
# Processing Record 44 of Set 12 | umm kaddadah
# Processing Record 45 of Set 12 | zhuanghe
# Processing Record 46 of Set 12 | vardo
# Processing Record 47 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 12 | okhotsk
# Processing Record 49 of Set 12 | sawakin
# Processing Record 50 of Set 12 | disna
# Processing Record 1 of Set 13 | aklavik
# Processing Record 2 of Set 13 | nchelenge
# Processing Record 3 of Set 13 | qeshm
# Processing Record 4 of Set 13 | nyagan
# Processing Record 5 of Set 13 | morwa
# Processing Record 6 of Set 13 | qitaihe
# Processing Record 7 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 13 | hohoe
# Processing Record 9 of Set 13 | entre rios
# Processing Record 10 of Set 13 | nueve de julio
# Processing Record 11 of Set 13 | korla
# Processing Record 12 of Set 13 | palmer
# Processing Record 13 of Set 13 | orissaare
# Processing Record 14 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 13 | ostrovnoy
# Processing Record 16 of Set 13 | brae
# Processing Record 17 of Set 13 | lensk
# Processing Record 18 of Set 13 | barcelos
# Processing Record 19 of Set 13 | kirovskiy
# Processing Record 20 of Set 13 | ormara
# Processing Record 21 of Set 13 | bonfim
# Processing Record 22 of Set 13 | tautira
# Processing Record 23 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 13 | naze
# Processing Record 25 of Set 13 | batemans bay
# Processing Record 26 of Set 13 | barmer
# Processing Record 27 of Set 13 | fougamou
# Processing Record 28 of Set 13 | sao domingos
# Processing Record 29 of Set 13 | cabras
# Processing Record 30 of Set 13 | arman
# Processing Record 31 of Set 13 | yilan
# Processing Record 32 of Set 13 | deputatskiy
# Processing Record 33 of Set 13 | tura
# Processing Record 34 of Set 13 | maridi
# Processing Record 35 of Set 13 | gorontalo
# Processing Record 36 of Set 13 | bogotol
# Processing Record 37 of Set 13 | baracoa
# Processing Record 38 of Set 13 | nalut
# Processing Record 39 of Set 13 | san andres
# Processing Record 40 of Set 13 | boa vista
# Processing Record 41 of Set 13 | les cayes
# Processing Record 42 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 43 of Set 13 | mtwara
# Processing Record 44 of Set 13 | katherine
# Processing Record 45 of Set 13 | makrikapa
# City not found. Skipping...
# Processing Record 46 of Set 13 | lokosovo
# Processing Record 47 of Set 13 | rabo de peixe
# Processing Record 48 of Set 13 | gamba
# Processing Record 49 of Set 13 | sanmenxia
# Processing Record 50 of Set 13 | saint-francois
# Processing Record 1 of Set 14 | sao joao dos patos
# Processing Record 2 of Set 14 | swan river
# Processing Record 3 of Set 14 | tecoanapa
# Processing Record 4 of Set 14 | hualmay
# Processing Record 5 of Set 14 | malayal
# Processing Record 6 of Set 14 | nizhniy tsasuchey
# Processing Record 7 of Set 14 | southbridge
# Processing Record 8 of Set 14 | baker city
# Processing Record 9 of Set 14 | mancio lima
# Processing Record 10 of Set 14 | camacupa
# Processing Record 11 of Set 14 | kot samaba
# Processing Record 12 of Set 14 | panaba
# Processing Record 13 of Set 14 | sinnar
# Processing Record 14 of Set 14 | zhoucheng
# Processing Record 15 of Set 14 | tokonou
# Processing Record 16 of Set 14 | kyshtovka
# Processing Record 17 of Set 14 | fare
# Processing Record 18 of Set 14 | inuvik
# Processing Record 19 of Set 14 | marystown
# Processing Record 20 of Set 14 | grove city
# Processing Record 21 of Set 14 | port macquarie
# Processing Record 22 of Set 14 | pitiquito
# Processing Record 23 of Set 14 | stabat
# Processing Record 24 of Set 14 | isangel
# Processing Record 25 of Set 14 | cape coast
# Processing Record 26 of Set 14 | paraiso
# Processing Record 27 of Set 14 | tebingtinggi
# Processing Record 28 of Set 14 | sorong
# Processing Record 29 of Set 14 | tobetsu
# Processing Record 30 of Set 14 | tambilil
# Processing Record 31 of Set 14 | marshfield
# Processing Record 32 of Set 14 | north ridgeville
# Processing Record 33 of Set 14 | cururupu
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | lesnoy
# Processing Record 36 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | skibbereen
# Processing Record 38 of Set 14 | severnyy
# Processing Record 39 of Set 14 | omsukchan
# Processing Record 40 of Set 14 | bataipora
# Processing Record 41 of Set 14 | miandrivazo
# Processing Record 42 of Set 14 | srivardhan
# Processing Record 43 of Set 14 | praya
# Processing Record 44 of Set 14 | celestun
# Processing Record 45 of Set 14 | cristalina
# Processing Record 46 of Set 14 | sazonovo
# Processing Record 47 of Set 14 | matara
# Processing Record 48 of Set 14 | barranca
# Processing Record 49 of Set 14 | maceio
# Processing Record 50 of Set 14 | yudong
# Processing Record 1 of Set 15 | gidam
# Processing Record 2 of Set 15 | villamontes
# Processing Record 3 of Set 15 | freeport
# Processing Record 4 of Set 15 | lima
# Processing Record 5 of Set 15 | dunedin
# Processing Record 6 of Set 15 | tombouctou
# Processing Record 7 of Set 15 | adre
# Processing Record 8 of Set 15 | flinders
# Processing Record 9 of Set 15 | vedaranniyam
# City not found. Skipping...
# Processing Record 10 of Set 15 | metro
# Processing Record 11 of Set 15 | baixa grande
# Processing Record 12 of Set 15 | seddon
# Processing Record 13 of Set 15 | sirajganj
# Processing Record 14 of Set 15 | kropotkin
# Processing Record 15 of Set 15 | mount isa
# Processing Record 16 of Set 15 | san policarpo
# Processing Record 17 of Set 15 | waipawa
# Processing Record 18 of Set 15 | nyimba
# Processing Record 19 of Set 15 | baleshwar
# Processing Record 20 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 15 | zeya
# Processing Record 22 of Set 15 | slavuta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     39.22        81          40
# 1       Butaritari      KI   3.0707  172.7902     82.02        77          12
# 2  Bambous Virieux      MU -20.3428   57.7575     73.65        73          40
# 3          Huarmey      PE -10.0681  -78.1522     65.97        69          25
# 4           Yarada      IN  17.6500   83.2667     86.32        79          40
# 5     Ponta Do Sol      PT  32.6667  -17.1000     78.01        69          40
# 6       Dromolaxia      CY  34.8761   33.5860     97.84        66          20
# 7        Jamestown      US  42.0970  -79.2353     74.05        60           0
# 8           Atuona      PF  -9.8000 -139.0333     77.92        68           2
# 9   Novosergiyevka      RU  52.0934   53.6528     76.53        62          97
#
#    Wind Speed Current Description
# 0       18.41    scattered clouds
# 1       15.64          light rain
# 2        3.44    scattered clouds
# 3        5.84    scattered clouds
# 4        4.61    scattered clouds
# 5        2.17    scattered clouds
# 6       11.50          few clouds
# 7        7.00           clear sky
# 8       20.24           clear sky
# 9        7.61     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
